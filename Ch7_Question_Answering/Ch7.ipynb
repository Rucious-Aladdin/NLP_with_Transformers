# %%
from google.colab import drive
drive.mount('/content/drive')

# 코랩을 사용하지 않으면 이 셀의 코드를 주석 처리하세요.
# !git clone https://github.com/rickiepark/nlp-with-transformers.git
# %cd nlp-with-transformers
from install import *
install_requirements(chapter=7)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into 'nlp-with-transformers'...
# remote: Enumerating objects: 653, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 653 (delta 47), reused 15 (delta 8), pack-reused 569
# Receiving objects: 100% (653/653), 62.41 MiB | 22.97 MiB/s, done.
# Resolving deltas: 100% (335/335), done.
# /content/nlp-with-transformers/nlp-with-transformers
# ⏳ Installing base requirements ...
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-85177c3e4b67> in <cell line: 8>()
#       6 get_ipython().run_line_magic('cd', 'nlp-with-transformers')
#       7 from install import *
# ----> 8 install_requirements(chapter=7)
#
# /content/nlp-with-transformers/install.py in install_requirements(chapter, is_chapter7, is_chapter8, is_chapter9)
#      44
#      45     if process_install.returncode != 0:
# ---> 46         raise Exception("😭 Failed to install base requirements")
#      47     else:
#      48         print("✅ Base requirements installed!")
#
# Exception: 😭 Failed to install base requirements

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Dataset

# %%
# !pip inatsll daa
from datasets import get_dataset_config_names, load_dataset

domains = get_dataset_config_names()
domains
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a5556b1f20a9> in <cell line: 1>()
# ----> 1 from datasets import get_dataset_config_names, load_dataset
#       2
#       3 domains = get_dataset_config_names()
#       4 domains
#
# ModuleNotFoundError: No module named 'datasets'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
